# %%
import pandas as pd

# Provided data
data = {
    "title": [
        "shree ashapura", "the brand gallery", "branded garment shop", "shoppers hub", "mr iB clothing",
        "99 fashion wear", "cotton culture", "zudio", "diva fashion", "kharat trends hub", "star fashion",
        "kajri", "forever pretty", "trends", "bangok collection", "peachmode", "kapra fashion", "pantaloons",
        "meena fashions", "forever 21", "fashion factory", "dhara", "three three", "globus fashion", "global desi",
        "manyavar", "culture", "style", "the raymond", "ridhi sidhi", "rajkamal", "anmol", "jockey", "vimala",
        "the plug", "h2", "mira designer", "fashion king", "shree collections", "viona"
    ],
    "price": [
        2000, 2500, 1500, 3000, 4700, 2200, 2400, 1200, 600, 3000, 4500, 1500, 900, 3200, 2250, 4000,
        2300, 1900, 1700, 2300, 3100, 3700, 1200, 2300, 3750, 4900, 3200, 2300, 4300, 3400, 6700, 5400,
        1400, 780, 3520, 3456, 4500, 3200, 2800, 990
    ],
    "lat": [
        19.022089, 19.030933, 19.025639, 19.032821, 19.037162, 19.016544, 19.014379, 19.025624, 19.021834,
        19.019804, 19.01473, 19.019794, 19.020092, 19.022615, 19.020004, 19.021902, 19.021936, 19.0222472,
        19.021221, 19.021898, 19.063595, 19.071918, 19.071456, 19.066127, 19.065725, 19.066033, 19.078646,
        19.066431, 19.071382, 19.061415, 19.054956, 19.062421, 19.064109, 19.064563, 19.063787, 19.060892,
        19.013683, 19.015624, 19.025594, 19.025459
    ],
    "long": [
        73.017311, 73.012314, 73.021535, 73.016605, 73.018861, 73.086503, 73.09121, 73.092044, 73.090707,
        73.088277, 73.092337, 73.088278, 73.016961, 73.017337, 73.016312, 73.017519, 73.017722, 73.017674,
        73.0218742, 73.017945, 72.997127, 73.001123, 73.001828, 73.001143, 73.001208, 73.00089, 72.997427,
        72.999328, 73.001707, 73.014168, 73.016185, 73.014045, 73.010622, 73.009391, 73.0141, 73.00392,
        73.038906, 73.040871, 73.04318, 73.043215
    ],
    "capacity": [
        69, 56, 78, 53, 89, 72, 55, 97, 45, 67, 56, 45, 19, 36, 34, 34, 67, 87, 55, 36, 34, 25, 56, 45,
        29, 34, 25, 76, 56, 34, 76, 23, 35, 21, 12, 58, 45, 56, 72, 56
    ],
    "rating": [
        4, 4.9, 3, 4.8, 3.6, 5, 4.8, 4.2, 3, 5, 4.6, 4.4, 4.9, 4.1, 4.9, 4.8, 4.7, 4.1, 4.4, 3.9, 4.1,
        4, 4.7, 3.9, 4.7, 4.6, 4.8, 4.3, 4.5, 5, 4.7, 3.5, 4.1, 5, 5, 4, 5, 4.9, 4.7, 3.3
    ],
    # Manually assigned (only 1 amenity per store)
    "amenities": [
        ['AC'],  
        ['street'],  
        ['regional'],  
        ['fastfashion'],  
        ['Area'],  
        ['AC'],  
        ['street'],  
        ['regional'],  
        ['fastfashion'],  
        ['Area'],  
        ['AC'],  
        ['street'],  
        ['regional'],  
        ['fastfashion'],  
        ['Area'],  
        ['AC'],  
        ['street'],  
        ['regional'],  
        ['fastfashion'],  
        ['Area'],  
        ['AC'],  
        ['street'],  
        ['regional'],  
        ['fastfashion'],  
        ['Area'],  
        ['AC'],  
        ['street'],  
        ['regional'],  
        ['fastfashion'],  
        ['Area'],  
        ['AC'],  
        ['street'],  
        ['regional'],  
        ['fastfashion'],  
        ['Area'],  
        ['AC'],  
        ['street'],  
        ['regional'],  
        ['fastfashion'],  
        ['Area']
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV
csv_path = r"d:\mini project\data preprocessing\data collection\retail_spaces_with_amenities.csv"
df.to_csv(csv_path, index=False)

df
